# %% [markdown]
# # TRPA Goshawk Threshold Zone — v1 (cell-by-cell)
#
# Build a single goshawk threshold zone for **one nest at a time**. Set `NEST_ID`
# in the configuration cell, then run cells top to bottom. Each cell is
# independently re-runnable.
#
# **Algorithm (simple v1):** 0.25-mi buffer around the nest + closest
# contiguous HIGH-then-MOD CWHR habitat polygons until area ≥ 500 ac (or
# no more contiguous candidates). Dissolve, fill interior holes only.
# No LOW tier, no relaxed-contiguity fallback, no morphological close.
#
# **Sources** (read-only):
# - Nests: `C:\GIS\Scratch.gdb\nogo_nest_usfs`
# - HIGH habitat: `C:\GIS\Scratch.gdb\amgo_ecobject_cwhr_habmodel_high`
# - MOD habitat: `C:\GIS\Scratch.gdb\amgo_ecobject_cwhr_habmodel_moderate`
#
# **Output:** `C:\GIS\Goshawk_Threshold_Zone.gdb\TRPA_Goshawk_Threshold_Zone_<NEST_ID>`
# (per-nest FC so test runs don't clobber each other).
#
# If a nest is too sparse to reach 500 ac contiguously, the zone is
# buffer + whatever HIGH/MOD touched it. A `WARNING` prints. That's the
# biologically defensible answer for a nest surrounded by water/urban.

# %% [markdown]
# ## 1. Setup — imports + helpers

# %%
import arcpy
import os
import time
import uuid

arcpy.env.overwriteOutput = True


def mem(prefix):
    """Generate a unique in_memory feature class path."""
    return fr"in_memory\{prefix}_{uuid.uuid4().hex[:8]}"


def clear_in_memory():
    """Wipe everything in the in_memory workspace."""
    try:
        arcpy.management.Delete("in_memory")
    except Exception as e:
        print(f"  [warn] clear_in_memory: {type(e).__name__}: {e}")


def ensure_file_gdb(gdb_path):
    """Create a file GDB if it doesn't exist."""
    if arcpy.Exists(gdb_path):
        return
    out_dir = os.path.dirname(gdb_path)
    out_name = os.path.basename(gdb_path)
    if not os.path.isdir(out_dir):
        os.makedirs(out_dir, exist_ok=True)
    arcpy.management.CreateFileGDB(out_dir, out_name)
    print(f"Created output GDB: {gdb_path}")


def add_acres(fc, field_name="Acres", method="AREA_GEODESIC"):
    """Compute (or recompute) Acres on the FC. Geodesic for output, AREA for work layers."""
    fields = {f.name for f in arcpy.ListFields(fc)}
    if field_name not in fields:
        arcpy.management.AddField(fc, field_name, "DOUBLE")
    arcpy.management.CalculateGeometryAttributes(
        fc, [[field_name, method]], area_unit="ACRES"
    )


def fill_interior_holes(poly_fc, out_path, hole_area_threshold=10**18):
    """Eliminate interior holes only. Multipart exterior parts are preserved."""
    arcpy.management.EliminatePolygonPart(
        in_features=poly_fc,
        out_feature_class=out_path,
        condition="AREA",
        part_area=hole_area_threshold,
        part_option="CONTAINED_ONLY",
    )
    return out_path


def sum_field(fc, field_name):
    """Sum a numeric field over an FC."""
    total = 0.0
    with arcpy.da.SearchCursor(fc, [field_name]) as cur:
        for (v,) in cur:
            total += float(v or 0.0)
    return total


# Wipe in_memory at start in case of leftovers from a prior run.
clear_in_memory()
print("Setup complete.")

# %% [markdown]
# ## 2. Configuration
#
# **All workspace + algorithm + validation config lives here**, in the
# single code cell below. Run this once per kernel session and any of
# the downstream sections (single-nest test, all-nests run, validation
# in §12, trim in §13) can be run independently.
#
# The per-nest selector — only used for the single-nest cell-by-cell
# workflow in §3–§10 — is the small cell after this one (§2.1).

# %%
# ==== WORKSPACES ====
SOURCE_GDB = r"C:\GIS\Scratch.gdb"
OUTPUT_GDB = r"C:\GIS\Goshawk_Threshold_Zone.gdb"

NESTS_FC = SOURCE_GDB + "\\" + "nogo_nest_usfs"
HAB_HIGH = SOURCE_GDB + "\\" + "amgo_ecobject_cwhr_habmodel_high"
HAB_MOD = SOURCE_GDB + "\\" + "amgo_ecobject_cwhr_habmodel_moderate"

arcpy.env.workspace = SOURCE_GDB
ensure_file_gdb(OUTPUT_GDB)

# ==== ALGORITHM PARAMETERS (single-nest test + all-nests run) ====
TARGET_AC = 500.0
BUFFER_DIST = "0.25 Miles"
SEARCH_RADIUS = "5 Miles"            # pre-clip habitat to this envelope
MIN_ACRES = 0.5                       # skip habitat slivers smaller than this
CLOSE_DIST = "200 Feet"               # morphological close radius (closes gaps <= 2x)
PROBE_EVERY = 5                       # picks between projected-total probes
PROBE_HOMESTRETCH_AC = 100            # within X ac of target, probe every pick
MAX_ITERS = 5000                      # safety cap on growth iterations

# ==== VALIDATION + TRIM PATHS (Section 12 & 13) ====
# The threshold-zone FC to validate / trim. Default = production output.
# Point this at a single-nest test FC (e.g. ..._2011A) to validate one nest.
THRESHOLD_FC = OUTPUT_GDB + "\\" + "TRPA_Goshawk_Threshold_Zone"

# Source veg layer for Identity #1 (threshold zones x veg).
VEG_SRC = r"C:\GIS\TahoeMaps\Tahoe_Data.gdb\Vegetation_Ecobject_2010"

# Caldor Fire Vegetation Burn Severity (REST layer Fire/5) for Identity #2.
FIRE_LAYER = "https://maps.trpa.org/server/rest/services/Fire/MapServer/5"
FIRE_FIELD = "gridcode"               # numeric severity code on the source layer
BURN_SEV_FIELD = "Burn_Sev"           # derived TEXT label we'll pivot on
BURN_SEV_LABELS = {                   # gridcode -> label, from the layer's renderer
    1: "Unburned/Very Low",
    2: "Low",
    3: "Moderate",
    4: "High",
}

# Output FCs for the validation overlays + the trim postprocess
ID1_FC = OUTPUT_GDB + "\\" + "TRPA_GTZ_x_Veg"
ID2_FC = OUTPUT_GDB + "\\" + "TRPA_GTZ_x_Veg_x_Fire"
TRIM_FC = OUTPUT_GDB + "\\" + "TRPA_Goshawk_Threshold_Zone_Trimmed"

# Echo so we can see what's wired up
print("Workspaces:")
print(f"  SOURCE_GDB:   {SOURCE_GDB}")
print(f"  OUTPUT_GDB:   {OUTPUT_GDB}")
print(f"  NESTS_FC:     {NESTS_FC}")
print(f"  HAB_HIGH:     {HAB_HIGH}")
print(f"  HAB_MOD:      {HAB_MOD}")
print(f"  VEG_SRC:      {VEG_SRC}")
print(f"  FIRE_LAYER:   {FIRE_LAYER}")
print()
print("Algorithm:")
print(f"  TARGET_AC={TARGET_AC} | BUFFER_DIST={BUFFER_DIST} | "
      f"SEARCH_RADIUS={SEARCH_RADIUS} | MIN_ACRES={MIN_ACRES}")
print(f"  CLOSE_DIST={CLOSE_DIST} | PROBE_EVERY={PROBE_EVERY} | "
      f"PROBE_HOMESTRETCH_AC={PROBE_HOMESTRETCH_AC}")
print()
print("Validation outputs:")
print(f"  THRESHOLD_FC: {THRESHOLD_FC}")
print(f"  ID1_FC:       {ID1_FC}")
print(f"  ID2_FC:       {ID2_FC}")
print(f"  TRIM_FC:      {TRIM_FC}")

# %% [markdown]
# ### 2.1 Pick a nest (single-nest test only)
#
# Set `NEST_ID` to one of the nest identifiers, then run the cell. The
# single-nest cells in §3–§10 use `nest_oid` and `nest_location` set
# here. Skip this cell entirely if you're only running the all-nests
# flow in §11 or the §12/§13 postprocess.
#
# Examples: `'2011A'` (Sierra Creek), `'2004J'` (Watson Creek),
# `'1978A'` (Bliss Creek).

# %%
NEST_ID = "2011A"   # change me

nest_oid = None
nest_location = None
with arcpy.da.SearchCursor(NESTS_FC, ["OBJECTID", "NEST_ID", "LOCATION"]) as cur:
    for oid, nid, loc in cur:
        if nid == NEST_ID:
            nest_oid = oid
            nest_location = loc
            break
if nest_oid is None:
    raise ValueError(f"NEST_ID {NEST_ID!r} not found in {NESTS_FC}")

print(f"NEST_ID:  {NEST_ID}")
print(f"OID:      {nest_oid}")
print(f"LOCATION: {nest_location!r}")

# %% [markdown]
# ## 3. 0.25-mile buffer around the nest
#
# The buffer is the foundational protected area. It must always be inside
# the final threshold zone — verify in ArcGIS Pro after running this cell.

# %%
nest_lyr = mem("nest")
arcpy.management.MakeFeatureLayer(NESTS_FC, nest_lyr, f"OBJECTID = {nest_oid}")

buf_fc = mem("buf")
arcpy.analysis.Buffer(nest_lyr, buf_fc, BUFFER_DIST, dissolve_option="ALL")
add_acres(buf_fc)
buf_ac = sum_field(buf_fc, "Acres")

print(f"Buffer FC: {buf_fc}")
print(f"BufAc:     {buf_ac:.2f} (need {TARGET_AC - buf_ac:.1f} more habitat)")

# %% [markdown]
# ## 4. Pre-clip HIGH + MOD to the 5-mile envelope, erase the buffer
#
# Basin-wide HIGH = ~113K polys, MOD = ~281K. Pre-clipping to the
# search envelope is what makes everything below run in seconds.
#
# `Erase` removes the buffer footprint from the work layers so habitat
# that overlaps the buffer isn't double-counted in the running total.

# %%
# Build the search envelope
search_buf = mem("search_buf")
arcpy.analysis.Buffer(nest_lyr, search_buf, SEARCH_RADIUS, dissolve_option="ALL")


def local_subset(src_fc, label):
    pre_lyr = mem(f"{label}_pre")
    arcpy.management.MakeFeatureLayer(src_fc, pre_lyr)
    arcpy.management.SelectLayerByLocation(pre_lyr, "INTERSECT", search_buf)
    local_fc = mem(f"{label}_local")
    arcpy.management.CopyFeatures(pre_lyr, local_fc)
    arcpy.management.Delete(pre_lyr)
    cnt = int(arcpy.management.GetCount(local_fc)[0])
    print(f"  {label.upper():4s} polys within {SEARCH_RADIUS}: {cnt}")
    return local_fc


high_local = local_subset(HAB_HIGH, "high")
mod_local = local_subset(HAB_MOD, "mod")

# Erase the buffer from each so we don't double-count overlap
high_work = mem("high_work")
mod_work = mem("mod_work")
arcpy.analysis.Erase(high_local, buf_fc, high_work)
arcpy.analysis.Erase(mod_local, buf_fc, mod_work)
print("Erased buffer from HIGH and MOD work layers.")

# %% [markdown]
# ## 5. Compute Acres + NEAR_DIST on the work layers
#
# `Acres` (geodesic) for the running total and the `min_acres` filter.
# `NEAR_DIST` (distance from each polygon to the nest point) is the
# basis for the greedy "closest first" pick order.

# %%
add_acres(high_work)
add_acres(mod_work)
arcpy.analysis.Near(high_work, nest_lyr)
arcpy.analysis.Near(mod_work, nest_lyr)

print(f"  HIGH: {int(arcpy.management.GetCount(high_work)[0])} polys, "
      f"sum acres = {sum_field(high_work, 'Acres'):.1f}")
print(f"  MOD:  {int(arcpy.management.GetCount(mod_work)[0])} polys, "
      f"sum acres = {sum_field(mod_work, 'Acres'):.1f}")

# %% [markdown]
# ## 6. Tiered HIGH → MOD growth with probe-based stop
#
# Phase 1: drain HIGH closest to the nest, polys that touch `current_fc`.
# Phase 2: tiered HIGH → ONE MOD → re-check HIGH → … until target met or
# no contiguous candidate in either tier.
#
# **Stop condition is post-close projected `TotalAc`, not pre-fill sum.**
# Every `PROBE_EVERY` picks (and every pick once pre-fill is within
# `PROBE_HOMESTRETCH_AC` of target), the algorithm runs the full final
# pipeline (Dissolve + hole-fill + morphological close + re-fill) on a
# copy of `current_fc` and measures geodesic acres. Growth stops as soon
# as the projected total reaches `TARGET_AC`. Without this, the close
# adds 30–180 ac of "Filled" on top of the pre-fill running sum and the
# final TotalAc overshoots by that amount.
#
# Picks are appended directly to `current_fc` via `InsertCursor`. No
# per-iteration Merge/Dissolve.

# %%
# Make feature layers for the SelectLayerByLocation calls
high_lyr = mem("high_lyr")
mod_lyr = mem("mod_lyr")
arcpy.management.MakeFeatureLayer(high_work, high_lyr)
arcpy.management.MakeFeatureLayer(mod_work, mod_lyr)

oid_high = arcpy.Describe(high_work).OIDFieldName
oid_mod = arcpy.Describe(mod_work).OIDFieldName

# current_fc starts as the buffer; each pick is appended to it
current_fc = mem("current")
arcpy.management.CopyFeatures(buf_fc, current_fc)

selected_high = set()
selected_mod = set()
high_added = 0.0
mod_added = 0.0

# Probe state. projected_total mirrors what the post-close TotalAc would
# be if we stopped now; updated by maybe_probe(). Starts at buf_ac since
# current_fc starts as the buffer.
projected_total = buf_ac
picks_since_probe = 0


def pick_best_contiguous(layer, oid_field, selected):
    """Closest-by-NEAR_DIST contiguous unselected polygon, ties broken by larger Acres."""
    arcpy.management.SelectLayerByLocation(
        layer, "INTERSECT", current_fc, selection_type="NEW_SELECTION"
    )
    best = None
    with arcpy.da.SearchCursor(layer, [oid_field, "Acres", "NEAR_DIST"]) as cur:
        for oid, ac, nd in cur:
            if oid in selected:
                continue
            ac = float(ac or 0.0)
            if ac < MIN_ACRES:
                continue
            nd = float(nd if nd is not None else 1e18)
            cand = (nd, -ac, oid)
            if best is None or cand < best:
                best = cand
    if best is None:
        return None
    return best[2], -best[1]


def append_to_footprint(work_fc, oid, oid_field):
    with arcpy.da.SearchCursor(
        work_fc, ["SHAPE@"], where_clause=f"{oid_field} = {oid}"
    ) as cur:
        for (g,) in cur:
            with arcpy.da.InsertCursor(current_fc, ["SHAPE@"]) as ic:
                ic.insertRow([g])
            return


def project_total_ac():
    """Run the full finalize pipeline on a copy of current_fc and return geodesic TotalAc.
    All probe intermediates are deleted before return."""
    diss = mem("probe_diss")
    arcpy.management.Dissolve(current_fc, diss)
    pre_close = mem("probe_pre_close")
    fill_interior_holes(diss, pre_close)
    close_out = mem("probe_close_out")
    arcpy.analysis.Buffer(pre_close, close_out, CLOSE_DIST)
    closed = mem("probe_closed")
    arcpy.analysis.Buffer(close_out, closed, f"-{CLOSE_DIST}")
    final = mem("probe_final")
    fill_interior_holes(closed, final)
    add_acres(final)
    total = sum_field(final, "Acres")
    for t in (diss, pre_close, close_out, closed, final):
        if arcpy.Exists(t):
            arcpy.management.Delete(t)
    return total


def maybe_probe():
    """Update projected_total if cadence rules say it's time."""
    global projected_total, picks_since_probe
    pre_fill = buf_ac + high_added + mod_added
    in_homestretch = pre_fill >= (TARGET_AC - PROBE_HOMESTRETCH_AC)
    if in_homestretch or picks_since_probe >= PROBE_EVERY:
        projected_total = project_total_ac()
        picks_since_probe = 0


def stopping():
    return projected_total >= TARGET_AC


t0 = time.time()
n_picks = 0

# Phase 1: drain HIGH while contiguous and below target (probe-based stop)
for _ in range(MAX_ITERS):
    if stopping():
        break
    pick = pick_best_contiguous(high_lyr, oid_high, selected_high)
    if pick is None:
        break
    oid, ac = pick
    selected_high.add(oid)
    high_added += ac
    n_picks += 1
    picks_since_probe += 1
    append_to_footprint(high_work, oid, oid_high)
    maybe_probe()

print(f"After HIGH phase: {n_picks} picks, high_added={high_added:.1f} ac, "
      f"projected_total={projected_total:.1f} ac")

# Phase 2: tiered HIGH-then-MOD until done or exhausted
for _ in range(MAX_ITERS):
    if stopping():
        break
    # Re-check HIGH first (new contiguity from a MOD pick may unlock more)
    pick = pick_best_contiguous(high_lyr, oid_high, selected_high)
    if pick is not None:
        oid, ac = pick
        selected_high.add(oid)
        high_added += ac
        n_picks += 1
        picks_since_probe += 1
        append_to_footprint(high_work, oid, oid_high)
        maybe_probe()
        continue
    # No HIGH; try MOD
    pick = pick_best_contiguous(mod_lyr, oid_mod, selected_mod)
    if pick is None:
        break
    oid, ac = pick
    selected_mod.add(oid)
    mod_added += ac
    n_picks += 1
    picks_since_probe += 1
    append_to_footprint(mod_work, oid, oid_mod)
    maybe_probe()

# Final probe so projected_total reflects the actual stop state
projected_total = project_total_ac()
dt = time.time() - t0
pre_fill = buf_ac + high_added + mod_added
print(f"Growth done: {n_picks} picks, high={high_added:.1f}, mod={mod_added:.1f}, "
      f"pre-fill={pre_fill:.1f}, projected_total={projected_total:.1f}, {dt:.1f}s")

# %% [markdown]
# ## 7. Dissolve + fill interior holes + morphological close
#
# `Dissolve` merges the buffer + appended polygons into one geometry.
# `EliminatePolygonPart` with `part_option="CONTAINED_ONLY"` (the default)
# fills only **interior holes** — multipart exterior parts are preserved
# so the buffer is always retained.
#
# Then a **morphological close** (`Buffer` outward by `CLOSE_DIST`, then
# `Buffer` inward by the same distance) collapses concavities and narrow
# channels narrower than `2 * CLOSE_DIST` (~400 ft at the default). This
# is what turns "spider with thin reaches" outputs into compact zones.
# A final `fill_interior_holes` pass catches any new interior holes the
# close enclosed.
#
# The earlier (broken) version used `part_option="ANY"` with a giant
# threshold, which silently deleted every multipart part except the
# largest. That's why some nests had been ending up not covered — fixed
# here.

# %%
# Step 1: Dissolve the buffer + appended picks into one geometry
dissolved = mem("dissolved")
arcpy.management.Dissolve(current_fc, dissolved)

# Step 2: Fill interior holes (real holes only - multipart exterior preserved)
pre_close = mem("pre_close")
fill_interior_holes(dissolved, pre_close)

# Step 3: Morphological close - buffer out then buffer in.
# Fills concavities/narrow channels narrower than 2 * CLOSE_DIST.
# In v1 (strict-only contiguity) the input is a single connected polygon,
# so close can only equal-or-grow it - no risk of part elimination.
close_out = mem("close_out")
arcpy.analysis.Buffer(pre_close, close_out, CLOSE_DIST)

closed = mem("closed")
arcpy.analysis.Buffer(close_out, closed, f"-{CLOSE_DIST}")

# Step 4: Re-fill any interior holes the close just enclosed
final_fc = mem("final")
fill_interior_holes(closed, final_fc)
add_acres(final_fc)
total_ac = sum_field(final_fc, "Acres")

short = total_ac < TARGET_AC - 0.01
print(f"TotalAc:  {total_ac:.2f}")
print(f"BufAc:    {buf_ac:.2f}")
print(f"HighAc:   {high_added:.2f}")
print(f"ModAc:    {mod_added:.2f}")
print(f"Filled:   {total_ac - (buf_ac + high_added + mod_added):.2f}  (interior hole-fill + morphological close)")
if short:
    print(f"\nWARNING: short of target ({total_ac:.1f} < {TARGET_AC}) - sparse-habitat nest.")

# %% [markdown]
# ## 8. Write the threshold zone to the output FC
#
# Per-nest output FC: `TRPA_Goshawk_Threshold_Zone_<NEST_ID>` in
# `Goshawk_Threshold_Zone.gdb`. Schema includes `NestID` (string from
# the nest layer), `NestOID` (OBJECTID), and `Location` so the row is
# self-identifying.

# %%
out_name = f"TRPA_Goshawk_Threshold_Zone_{NEST_ID}"
out_fc = OUTPUT_GDB + "\\" + out_name

if arcpy.Exists(out_fc):
    arcpy.management.Delete(out_fc)

sr = arcpy.Describe(HAB_HIGH).spatialReference
arcpy.management.CreateFeatureclass(OUTPUT_GDB, out_name, "POLYGON", spatial_reference=sr)
for fn, ft in [
    ("NestID", "TEXT"),
    ("NestOID", "LONG"),
    ("Location", "TEXT"),
    ("BufAc", "DOUBLE"),
    ("HighAc", "DOUBLE"),
    ("ModAc", "DOUBLE"),
    ("TotalAc", "DOUBLE"),
]:
    if ft == "TEXT":
        arcpy.management.AddField(out_fc, fn, ft, field_length=64)
    else:
        arcpy.management.AddField(out_fc, fn, ft)

with arcpy.da.InsertCursor(
    out_fc,
    ["SHAPE@", "NestID", "NestOID", "Location", "BufAc", "HighAc", "ModAc", "TotalAc"],
) as ic:
    for (geom,) in arcpy.da.SearchCursor(final_fc, ["SHAPE@"]):
        ic.insertRow([
            geom, NEST_ID, nest_oid, nest_location,
            float(buf_ac), float(high_added), float(mod_added), float(total_ac),
        ])

print(f"Wrote: {out_fc}")

# %% [markdown]
# ## 9. Sanity check
#
# Confirm the nest point is inside the threshold zone, and the area is
# in the expected range. If `contains == False`, something is broken —
# do not use this output for review.

# %%
with arcpy.da.SearchCursor(NESTS_FC, ["SHAPE@"], where_clause=f"OBJECTID = {nest_oid}") as cur:
    nest_pt = next(cur)[0]
with arcpy.da.SearchCursor(final_fc, ["SHAPE@"]) as cur:
    poly = next(cur)[0]

contains = poly.contains(nest_pt)
pre_fill = buf_ac + high_added + mod_added

print(f"Nest at: ({nest_pt.firstPoint.X:.1f}, {nest_pt.firstPoint.Y:.1f})")
print(f"Polygon part count: {poly.partCount}")
print(f"Threshold zone contains nest:  {contains}")
print(f"BufAc + HighAc + ModAc       = {pre_fill:.2f}")
print(f"TotalAc                      = {total_ac:.2f}")
print(f"Filled (interior holes only) = {total_ac - pre_fill:.2f}")

if not contains:
    print("\n!!! BUG: nest point is NOT inside the threshold zone — investigate before trusting this output.")
elif total_ac < TARGET_AC - 0.01:
    print(f"\nNote: short of {TARGET_AC} ac. Sparse-habitat nest — buffer + max contiguous habitat retained.")
elif total_ac > TARGET_AC + 200:
    print(f"\nNote: significantly over target ({total_ac - TARGET_AC:.0f} ac over). Last pick was large.")
else:
    print(f"\nLooks reasonable.")

# %% [markdown]
# ## 10. Cleanup
#
# Wipes in_memory before you move on to the next nest. Re-run the
# configuration cell with a different `NEST_ID`, then re-run cells 3–9.

# %%
clear_in_memory()
print("in_memory cleared. Ready for the next NEST_ID.")

# %% [markdown]
# ## 11. All-nests run
#
# Loops over every nest in `nogo_nest_usfs`, runs the full v1 pipeline
# (buffer → pre-clip → erase → acres+near → tiered HIGH→MOD with probe-
# based stop → dissolve → fill → close → re-fill), and writes one row
# per nest to a single output FC.
#
# **Output:** `C:\GIS\Goshawk_Threshold_Zone.gdb\TRPA_Goshawk_Threshold_Zone`
# (no `_<NEST_ID>` suffix — this is the production output). Per-nest
# test outputs from cells above are NOT clobbered.
#
# Cell 1: defines the `build_zone_for_nest()` function (just packages
# cells 6–14 into one callable). Cell 2: runs it for all 136 nests.
#
# Expected runtime: ~2–3 min/nest × 136 ≈ 5–7 hours.

# %%
def build_zone_for_nest(nest_oid, nest_id, location):
    """
    Run the v1 pipeline for one nest. Returns
        (final_geom, buf_ac, high_added, mod_added, total_ac, n_picks, dt)
    or raises if the pipeline blows up. Cleans up its in_memory temps
    via mem(...) paths (caller should call clear_in_memory() between nests
    if running many).
    """
    t0 = time.time()

    # ---- Buffer ----
    nest_lyr = mem("nest")
    arcpy.management.MakeFeatureLayer(NESTS_FC, nest_lyr, f"OBJECTID = {nest_oid}")
    buf_fc = mem("buf")
    arcpy.analysis.Buffer(nest_lyr, buf_fc, BUFFER_DIST, dissolve_option="ALL")
    add_acres(buf_fc)
    buf_ac = sum_field(buf_fc, "Acres")

    # ---- Pre-clip HIGH and MOD ----
    search_buf = mem("search_buf")
    arcpy.analysis.Buffer(nest_lyr, search_buf, SEARCH_RADIUS, dissolve_option="ALL")

    def local_subset(src_fc, label):
        pre_lyr = mem(f"{label}_pre")
        arcpy.management.MakeFeatureLayer(src_fc, pre_lyr)
        arcpy.management.SelectLayerByLocation(pre_lyr, "INTERSECT", search_buf)
        local_fc = mem(f"{label}_local")
        arcpy.management.CopyFeatures(pre_lyr, local_fc)
        arcpy.management.Delete(pre_lyr)
        return local_fc

    high_local = local_subset(HAB_HIGH, "high")
    mod_local = local_subset(HAB_MOD, "mod")

    # ---- Erase buffer from work layers ----
    high_work = mem("high_work")
    mod_work = mem("mod_work")
    arcpy.analysis.Erase(high_local, buf_fc, high_work)
    arcpy.analysis.Erase(mod_local, buf_fc, mod_work)

    # ---- Acres + Near ----
    add_acres(high_work)
    add_acres(mod_work)
    arcpy.analysis.Near(high_work, nest_lyr)
    arcpy.analysis.Near(mod_work, nest_lyr)

    # ---- Tiered growth with probe-based stop ----
    high_lyr = mem("high_lyr")
    mod_lyr = mem("mod_lyr")
    arcpy.management.MakeFeatureLayer(high_work, high_lyr)
    arcpy.management.MakeFeatureLayer(mod_work, mod_lyr)
    oid_high = arcpy.Describe(high_work).OIDFieldName
    oid_mod = arcpy.Describe(mod_work).OIDFieldName

    current_fc = mem("current")
    arcpy.management.CopyFeatures(buf_fc, current_fc)

    selected_high = set()
    selected_mod = set()
    high_added = 0.0
    mod_added = 0.0
    projected_total = buf_ac
    picks_since_probe = 0

    def pick_best_contiguous(layer, oid_field, selected):
        arcpy.management.SelectLayerByLocation(
            layer, "INTERSECT", current_fc, selection_type="NEW_SELECTION"
        )
        best = None
        with arcpy.da.SearchCursor(layer, [oid_field, "Acres", "NEAR_DIST"]) as cur:
            for oid, ac, nd in cur:
                if oid in selected:
                    continue
                ac = float(ac or 0.0)
                if ac < MIN_ACRES:
                    continue
                nd = float(nd if nd is not None else 1e18)
                cand = (nd, -ac, oid)
                if best is None or cand < best:
                    best = cand
        if best is None:
            return None
        return best[2], -best[1]

    def append_to_footprint(work_fc, oid, oid_field):
        with arcpy.da.SearchCursor(
            work_fc, ["SHAPE@"], where_clause=f"{oid_field} = {oid}"
        ) as cur:
            for (g,) in cur:
                with arcpy.da.InsertCursor(current_fc, ["SHAPE@"]) as ic:
                    ic.insertRow([g])
                return

    def project_total_ac():
        diss_p = mem("probe_diss")
        arcpy.management.Dissolve(current_fc, diss_p)
        pre_close_p = mem("probe_pre_close")
        fill_interior_holes(diss_p, pre_close_p)
        close_out_p = mem("probe_close_out")
        arcpy.analysis.Buffer(pre_close_p, close_out_p, CLOSE_DIST)
        closed_p = mem("probe_closed")
        arcpy.analysis.Buffer(close_out_p, closed_p, f"-{CLOSE_DIST}")
        final_p = mem("probe_final")
        fill_interior_holes(closed_p, final_p)
        add_acres(final_p)
        total = sum_field(final_p, "Acres")
        for t in (diss_p, pre_close_p, close_out_p, closed_p, final_p):
            if arcpy.Exists(t):
                arcpy.management.Delete(t)
        return total

    n_picks = 0

    # Phase 1: drain HIGH
    for _ in range(MAX_ITERS):
        if projected_total >= TARGET_AC:
            break
        pick = pick_best_contiguous(high_lyr, oid_high, selected_high)
        if pick is None:
            break
        oid, ac = pick
        selected_high.add(oid)
        high_added += ac
        n_picks += 1
        picks_since_probe += 1
        append_to_footprint(high_work, oid, oid_high)
        pre_fill = buf_ac + high_added + mod_added
        in_homestretch = pre_fill >= (TARGET_AC - PROBE_HOMESTRETCH_AC)
        if in_homestretch or picks_since_probe >= PROBE_EVERY:
            projected_total = project_total_ac()
            picks_since_probe = 0

    # Phase 2: tiered HIGH -> ONE MOD -> back to HIGH
    for _ in range(MAX_ITERS):
        if projected_total >= TARGET_AC:
            break
        pick = pick_best_contiguous(high_lyr, oid_high, selected_high)
        if pick is not None:
            oid, ac = pick
            selected_high.add(oid)
            high_added += ac
            n_picks += 1
            picks_since_probe += 1
            append_to_footprint(high_work, oid, oid_high)
        else:
            pick = pick_best_contiguous(mod_lyr, oid_mod, selected_mod)
            if pick is None:
                break
            oid, ac = pick
            selected_mod.add(oid)
            mod_added += ac
            n_picks += 1
            picks_since_probe += 1
            append_to_footprint(mod_work, oid, oid_mod)
        pre_fill = buf_ac + high_added + mod_added
        in_homestretch = pre_fill >= (TARGET_AC - PROBE_HOMESTRETCH_AC)
        if in_homestretch or picks_since_probe >= PROBE_EVERY:
            projected_total = project_total_ac()
            picks_since_probe = 0

    # ---- Finalize ----
    dissolved = mem("dissolved")
    arcpy.management.Dissolve(current_fc, dissolved)
    pre_close = mem("pre_close")
    fill_interior_holes(dissolved, pre_close)
    close_out = mem("close_out")
    arcpy.analysis.Buffer(pre_close, close_out, CLOSE_DIST)
    closed = mem("closed")
    arcpy.analysis.Buffer(close_out, closed, f"-{CLOSE_DIST}")
    final_fc = mem("final")
    fill_interior_holes(closed, final_fc)
    add_acres(final_fc)
    total_ac = sum_field(final_fc, "Acres")

    # Pull out the single geometry to return
    with arcpy.da.SearchCursor(final_fc, ["SHAPE@"]) as cur:
        final_geom = next(cur)[0]

    dt = time.time() - t0
    return final_geom, buf_ac, high_added, mod_added, total_ac, n_picks, dt


print("build_zone_for_nest() defined.")

# %%
# ==== ALL-NESTS PRODUCTION RUN ====
# Writes one row per nest to TRPA_Goshawk_Threshold_Zone (no suffix).
# Per-nest test outputs from cells above are NOT touched.

OUTPUT_NAME = "TRPA_Goshawk_Threshold_Zone"
out_fc = OUTPUT_GDB + "\\" + OUTPUT_NAME

# Recreate the output FC fresh
if arcpy.Exists(out_fc):
    arcpy.management.Delete(out_fc)
sr = arcpy.Describe(HAB_HIGH).spatialReference
arcpy.management.CreateFeatureclass(OUTPUT_GDB, OUTPUT_NAME, "POLYGON", spatial_reference=sr)
for fn, ft, kw in [
    ("NestID", "TEXT", {"field_length": 64}),
    ("NestOID", "LONG", {}),
    ("Location", "TEXT", {"field_length": 128}),
    ("BufAc", "DOUBLE", {}),
    ("HighAc", "DOUBLE", {}),
    ("ModAc", "DOUBLE", {}),
    ("TotalAc", "DOUBLE", {}),
    ("Picks", "LONG", {}),
    ("Sec", "DOUBLE", {}),
    ("Short", "SHORT", {}),  # 1 if total < target, else 0
]:
    arcpy.management.AddField(out_fc, fn, ft, **kw)

# Pull all nests
all_nests = []
with arcpy.da.SearchCursor(NESTS_FC, ["OBJECTID", "NEST_ID", "LOCATION"]) as cur:
    for oid, nid, loc in cur:
        all_nests.append((oid, nid, loc))
print(f"Nests to process: {len(all_nests)}")
print(f"Output FC: {out_fc}")
print()

t_start = time.time()
shorts = []
failures = 0

ic_fields = [
    "SHAPE@", "NestID", "NestOID", "Location",
    "BufAc", "HighAc", "ModAc", "TotalAc", "Picks", "Sec", "Short",
]

with arcpy.da.InsertCursor(out_fc, ic_fields) as ic:
    for i, (oid, nid, loc) in enumerate(all_nests, 1):
        try:
            geom, buf_ac, high_a, mod_a, total_ac, n_picks, dt = build_zone_for_nest(
                oid, nid, loc
            )
            short = 1 if total_ac < TARGET_AC - 0.01 else 0
            if short:
                shorts.append(nid)
            ic.insertRow([
                geom, nid, oid, loc,
                float(buf_ac), float(high_a), float(mod_a),
                float(total_ac), int(n_picks), float(dt), short,
            ])
            warn = "  WARNING short" if short else ""
            print(f"[{i:3d}/{len(all_nests)}] {nid:6s} {loc[:30]:30s} "
                  f"Total={total_ac:6.1f}  picks={n_picks:3d}  {dt:5.1f}s{warn}")
        except Exception as e:
            failures += 1
            print(f"[{i:3d}/{len(all_nests)}] {nid:6s}  ERROR: {type(e).__name__}: {e}")
        finally:
            # Clean up per-nest in_memory temps so we don't pile up across 136 iterations
            clear_in_memory()

elapsed = time.time() - t_start
print()
print("=" * 60)
print(f"Done. Output: {out_fc}")
print(f"Processed: {len(all_nests)} | failures: {failures} | shorts: {len(shorts)} | "
      f"elapsed: {elapsed/60:.1f} min")
if shorts:
    print(f"Short NEST_IDs: {shorts}")

# %% [markdown]
# ## 12. Validation + reporting
#
# Once `TRPA_Goshawk_Threshold_Zone` is populated, this section runs
# two `arcpy.analysis.Identity` overlays and pivots the result into
# per-nest acreage tables.
#
# 1. **Identity #1 (threshold zones × veg).** Each output piece
#    carries the threshold zone's `NestID`/`Location`/etc. plus the
#    underlying veg attributes (`WHRTYPE`, `WHRSIZE`, `WHRDENSITY`,
#    `CWHR`, `COVERTYPE`, `WHRLIFEFORM`).
# 2. **Identity #2 (× Caldor Fire burn severity).** Layers `gridcode`
#    1–4 onto each piece; we derive `Burn_Sev` text labels via the
#    `BURN_SEV_LABELS` mapping from §2.
# 3. **Acres** (geodesic) on every piece.
# 4. **Pandas pivots.** Per-nest by CWHR, per-nest by Burn_Sev,
#    CWHR × Burn_Sev basin-wide.
#
# All paths and parameters are set in §2. Run cells in order; each
# writes a separate FC so you can inspect intermediates in Pro.

# %% [markdown]
# ### 12.1 Identity #1 — threshold zones × veg
#
# `arcpy.analysis.Identity` with `THRESHOLD_FC` as the in-features and
# `VEG_SRC` as the identity-features. Each output piece carries all the
# threshold-zone attributes plus the veg attributes from the underlying
# ecobject polygon.
#
# Note: this can take a few minutes — `Vegetation_Ecobject_2010` is
# ~700K polygons basin-wide.

# %%
import time

t0 = time.time()
if arcpy.Exists(ID1_FC):
    arcpy.management.Delete(ID1_FC)

arcpy.analysis.Identity(
    in_features=THRESHOLD_FC,
    identity_features=VEG_SRC,
    out_feature_class=ID1_FC,
    join_attributes="ALL",
)
print(f"Identity #1 done in {time.time()-t0:.1f}s")
print(f"  Pieces: {int(arcpy.management.GetCount(ID1_FC)[0])}")
print(f"  Path:   {ID1_FC}")

# %% [markdown]
# ### 12.2 Identity #2 — result × Caldor Fire burn severity
#
# Layers `gridcode` from the Caldor Fire layer onto each piece, then
# derives a `Burn_Sev` text field with the renderer's labels
# (`"Unburned/Very Low"`, `"Low"`, `"Moderate"`, `"High"`).
#
# Pieces that fall outside the Caldor burn perimeter get `gridcode = None`
# and `Burn_Sev = None` (treated as "not in the burn footprint" in the
# pivots — typically these are nests far from the Caldor footprint).

# %%
t0 = time.time()
if arcpy.Exists(ID2_FC):
    arcpy.management.Delete(ID2_FC)

arcpy.analysis.Identity(
    in_features=ID1_FC,
    identity_features=FIRE_LAYER,
    out_feature_class=ID2_FC,
    join_attributes="ALL",
)
print(f"Identity #2 done in {time.time()-t0:.1f}s")
print(f"  Pieces: {int(arcpy.management.GetCount(ID2_FC)[0])}")

# Derive a friendly Burn_Sev text field from gridcode
existing = {f.name for f in arcpy.ListFields(ID2_FC)}
if BURN_SEV_FIELD not in existing:
    arcpy.management.AddField(ID2_FC, BURN_SEV_FIELD, "TEXT", field_length=24)

codeblock = (
    "def _label(gc):\n"
    f"    m = {BURN_SEV_LABELS!r}\n"
    "    return m.get(gc) if gc is not None else None\n"
)
arcpy.management.CalculateField(
    ID2_FC, BURN_SEV_FIELD, f"_label(!{FIRE_FIELD}!)", "PYTHON3", codeblock
)

# Quick distribution check
distrib = {}
with arcpy.da.SearchCursor(ID2_FC, [BURN_SEV_FIELD]) as cur:
    for (v,) in cur:
        distrib[v] = distrib.get(v, 0) + 1
print(f"Burn_Sev distribution (piece counts):")
for k in sorted(distrib, key=lambda x: (x is None, x or "")):
    print(f"  {k!r}: {distrib[k]:,}")
print(f"  Path: {ID2_FC}")

# %% [markdown]
# ### 12.3 Recompute geodesic acres on every piece
#
# Identity preserves the original `Acres` fields from each parent layer
# (parent-polygon acres, not piece acres). Add a fresh `PieceAc`
# (geodesic) on **`ID1_FC` always** (the trim in §13 needs it) and on
# `ID2_FC` if it exists (the burn-severity pivots in §12.4 need it
# there). Sets `report_fc` to whichever stage is most recent for
# downstream pivots.

# %%
# Always recompute on ID1 (trim §13 needs it)
add_acres(ID1_FC, field_name="PieceAc", method="AREA_GEODESIC")
print(f"PieceAc on ID1_FC: {int(arcpy.management.GetCount(ID1_FC)[0]):,} pieces, "
      f"sum = {sum_field(ID1_FC, 'PieceAc'):,.1f} ac")

# And on ID2 if it exists (pivots use the most recent stage)
if arcpy.Exists(ID2_FC):
    add_acres(ID2_FC, field_name="PieceAc", method="AREA_GEODESIC")
    print(f"PieceAc on ID2_FC: {int(arcpy.management.GetCount(ID2_FC)[0]):,} pieces, "
          f"sum = {sum_field(ID2_FC, 'PieceAc'):,.1f} ac")

report_fc = ID2_FC if arcpy.Exists(ID2_FC) else ID1_FC
print(f"\nreport_fc set to: {report_fc}")

# %% [markdown]
# ### 12.4 Load to pandas + pivot
#
# Pulls the validation FC into a `pandas.DataFrame` and produces three
# pivots:
#
# - **By nest × CWHR type** — habitat composition inside each nest's zone.
# - **By nest × burn severity** — how each nest's zone maps onto Caldor
#   burn severity.
# - **CWHR × burn severity** — basin-wide cross-tab of habitat type vs.
#   fire severity inside threshold zones.

# %%
import pandas as pd

all_fields = {f.name for f in arcpy.ListFields(report_fc)}
base_fields = ["NestID", "Location", "PieceAc"]
veg_fields = [f for f in ("WHRTYPE", "WHRSIZE", "WHRDENSITY", "CWHR",
                          "COVERTYPE", "WHRLIFEFORM") if f in all_fields]
burn_fields = [BURN_SEV_FIELD] if BURN_SEV_FIELD in all_fields else []

pull_fields = base_fields + veg_fields + burn_fields
print(f"Pulling fields: {pull_fields}")

rows = []
with arcpy.da.SearchCursor(report_fc, pull_fields) as cur:
    for r in cur:
        rows.append(r)
df = pd.DataFrame(rows, columns=pull_fields)
print(f"DataFrame shape: {df.shape}")
df.head()

# %%
# ---- Pivot 1: per-nest x CWHR type ----
if "CWHR" in df.columns:
    pivot_nest_cwhr = (
        df.pivot_table(
            index=["NestID", "Location"],
            columns="CWHR",
            values="PieceAc",
            aggfunc="sum",
            fill_value=0.0,
        )
        .round(1)
    )
    pivot_nest_cwhr["__total"] = pivot_nest_cwhr.sum(axis=1)
    print("Per-nest x CWHR type (top 15 by total acres):")
    display(pivot_nest_cwhr.sort_values("__total", ascending=False).head(15))

# %%
# ---- Pivot 2: per-nest x Burn_Sev ----
if BURN_SEV_FIELD in df.columns:
    # Order Burn_Sev categories sensibly
    sev_order = ["Unburned/Very Low", "Low", "Moderate", "High"]
    df["_sev"] = pd.Categorical(df[BURN_SEV_FIELD], categories=sev_order, ordered=True)
    pivot_nest_burn = (
        df.pivot_table(
            index=["NestID", "Location"],
            columns="_sev",
            values="PieceAc",
            aggfunc="sum",
            fill_value=0.0,
            observed=False,
        )
        .round(1)
    )
    # Add an "outside-burn" column from rows where BURN_SEV_FIELD is null
    outside = (
        df[df[BURN_SEV_FIELD].isna()]
        .groupby(["NestID", "Location"])["PieceAc"]
        .sum()
        .round(1)
        .rename("Outside Caldor")
    )
    pivot_nest_burn = pivot_nest_burn.join(outside, how="left").fillna(0.0)
    pivot_nest_burn["__total"] = pivot_nest_burn.sum(axis=1)
    print(f"Per-nest x {BURN_SEV_FIELD}:")
    display(pivot_nest_burn.sort_values("__total", ascending=False).head(15))

# %%
# ---- Pivot 3: CWHR x Burn_Sev (basin-wide) ----
if "CWHR" in df.columns and BURN_SEV_FIELD in df.columns:
    sev_order = ["Unburned/Very Low", "Low", "Moderate", "High"]
    df["_sev"] = pd.Categorical(df[BURN_SEV_FIELD], categories=sev_order, ordered=True)
    pivot_cwhr_burn = (
        df.dropna(subset=[BURN_SEV_FIELD])
          .pivot_table(
              index="CWHR",
              columns="_sev",
              values="PieceAc",
              aggfunc="sum",
              fill_value=0.0,
              observed=False,
          )
          .round(1)
    )
    pivot_cwhr_burn["__total"] = pivot_cwhr_burn.sum(axis=1)
    print(f"CWHR x {BURN_SEV_FIELD} (top 25 by total burned acres):")
    display(pivot_cwhr_burn.sort_values("__total", ascending=False).head(25))

# %% [markdown]
# ### 12.5 Optional: write pivots to disk
#
# Uncomment to drop CSVs into `Wildlife/outputs/` for sharing.

# %%
# from pathlib import Path
# OUTPUTS_DIR = Path(r"C:\Users\mbindl\Documents\GitHub\Monitoring\Wildlife\outputs")
# OUTPUTS_DIR.mkdir(exist_ok=True)
# stamp = time.strftime("%Y-%m-%d_%H%M%S")
# if "pivot_nest_cwhr" in dir():
#     pivot_nest_cwhr.to_csv(OUTPUTS_DIR / f"pivot_nest_cwhr_{stamp}.csv")
# if "pivot_nest_burn" in dir():
#     pivot_nest_burn.to_csv(OUTPUTS_DIR / f"pivot_nest_burn_{stamp}.csv")
# if "pivot_cwhr_burn" in dir():
#     pivot_cwhr_burn.to_csv(OUTPUTS_DIR / f"pivot_cwhr_burn_{stamp}.csv")
# print(f"Wrote pivots to {OUTPUTS_DIR}")

# %% [markdown]
# ## 13. Trim to ≤ TARGET_AC (post-process)
#
# The probe-based stop catches most overshoots, but the morphological
# close still pushes some nests over (the close adds 30–280 ac on top
# of the picked habitat for nests with concave/fragmented habitat).
# This section trims any nest with `TotalAc > TARGET_AC` back down,
# following real veg polygon boundaries from the Identity-#1 result.
#
# **Algorithm.** For each over-target nest:
#
# 1. Pull every piece of that nest's threshold zone from `ID1_FC`
#    (each piece is one threshold-zone × veg intersection — already
#    has `PieceAc` from cell 12.4).
# 2. Compute each piece's distance to its parent nest point. Buffer
#    pieces are at distance 0; outermost close-fill bits are far.
# 3. Sort pieces ascending by that distance.
# 4. Cumulative-sum `PieceAc`. Stop when adding the next piece would
#    push the total past `TARGET_AC`. Drop that piece and everything
#    beyond.
# 5. Dissolve kept pieces into one trimmed polygon. Recompute
#    geodesic acres.
#
# Kept pieces always include the buffer (distance 0), so the nest is
# guaranteed to be inside the trimmed zone. Under-target nests are
# copied through unchanged.
#
# Output FC: `TRPA_Goshawk_Threshold_Zone_Trimmed` — same schema as the
# production zone with two extra fields: `OrigAc` (the pre-trim TotalAc)
# and `Trimmed` (1 if this row was trimmed, 0 otherwise).

# %% [markdown]
# ### 13.1 Sanity check the inputs
#
# `ID1_FC` and the per-piece `PieceAc` field need to exist (run cells
# 12.1, 12.2, and 12.4 first). `THRESHOLD_FC` is the production zone
# from cell 12.1.

# %%
assert arcpy.Exists(THRESHOLD_FC), f"THRESHOLD_FC missing - run §2 config + §11 production run"
assert arcpy.Exists(ID1_FC), f"ID1_FC missing - run §12.1 Identity #1"
id1_fields = {f.name for f in arcpy.ListFields(ID1_FC)}
assert "PieceAc" in id1_fields, "PieceAc missing on ID1_FC - run §12.3 add_acres first"
assert "NestID" in id1_fields and "NestOID" in id1_fields, \
    "NestID/NestOID missing on ID1_FC - re-run §12.1"
print(f"THRESHOLD_FC: {THRESHOLD_FC}")
print(f"ID1_FC:       {ID1_FC}")
print(f"Pieces:       {int(arcpy.management.GetCount(ID1_FC)[0]):,}")

# %% [markdown]
# ### 13.2 Compute distance from each piece to its parent nest
#
# Per-piece geodesic distance using `geom.distanceTo(nest_geom)` in
# Python. We can't use `arcpy.analysis.Near(ID1_FC, NESTS_FC)` because
# that would assign the *globally nearest* nest to each piece (wrong for
# pieces far from their parent when another nest is closer); we need
# distance to each piece's *own* `NestOID`.
#
# Stored in a Python dict, keyed by `OBJECTID` of the piece — used by
# the trim loop below.

# %%
import time

t0 = time.time()
# Build NestOID -> nest geometry
nest_geoms = {}
with arcpy.da.SearchCursor(NESTS_FC, ["OBJECTID", "SHAPE@"]) as cur:
    for oid, g in cur:
        nest_geoms[oid] = g

oid_field_id1 = arcpy.Describe(ID1_FC).OIDFieldName
piece_dist = {}
piece_records = []  # (piece_oid, nest_id, piece_ac, dist)
with arcpy.da.SearchCursor(
    ID1_FC, [oid_field_id1, "NestID", "NestOID", "PieceAc", "SHAPE@"]
) as cur:
    for poid, nid, noid, pa, geom in cur:
        ng = nest_geoms.get(noid)
        if ng is None or geom is None:
            d = float("inf")
        else:
            d = geom.distanceTo(ng)
        piece_dist[poid] = d
        piece_records.append((poid, nid, float(pa or 0.0), d))
print(f"Distances computed for {len(piece_records):,} pieces in {time.time()-t0:.1f}s")

# %% [markdown]
# ### 13.3 Group pieces by nest, decide which to keep for over-target nests
#
# Builds a per-nest sorted list of pieces (ascending by distance), then
# walks each over-target nest's list cumulative-summing `PieceAc` until
# the next piece would push past `TARGET_AC`.

# %%
# Group pieces by NestID, sorted ascending by distance
pieces_by_nest = {}
for poid, nid, pa, d in piece_records:
    pieces_by_nest.setdefault(nid, []).append((poid, pa, d))
for nid in pieces_by_nest:
    pieces_by_nest[nid].sort(key=lambda r: r[2])

# Read THRESHOLD_FC to find over-target nests
over_target = []  # (nest_id, total_ac)
all_threshold_rows = {}
with arcpy.da.SearchCursor(
    THRESHOLD_FC,
    ["NestID", "NestOID", "Location", "BufAc", "HighAc", "ModAc",
     "TotalAc", "Picks", "Sec", "SHAPE@"],
) as cur:
    for nid, noid, loc, ba, ha, ma, ta, picks, sec, geom in cur:
        all_threshold_rows[nid] = (noid, loc, ba, ha, ma, ta, picks, sec, geom)
        if ta is not None and ta > TARGET_AC + 0.01:
            over_target.append((nid, ta))

print(f"Threshold zones total:    {len(all_threshold_rows)}")
print(f"Over target ({TARGET_AC:.0f} ac): {len(over_target)}")

# Decide kept-piece OIDs per over-target nest
keep_oids_per_nest = {}
for nid, ta in over_target:
    pieces = pieces_by_nest.get(nid, [])
    keep = []
    running = 0.0
    for poid, pa, d in pieces:
        if running + pa > TARGET_AC:
            break
        keep.append(poid)
        running += pa
    keep_oids_per_nest[nid] = (keep, running)

# Quick preview of how much trim each one needs
sample = sorted(over_target, key=lambda x: -x[1])[:10]
print(f"\nTop 10 overshoots (before trim):")
for nid, ta in sample:
    kept = keep_oids_per_nest.get(nid, ([], 0.0))
    print(f"  {nid:6s}  orig={ta:7.1f}  keep={len(kept[0]):3d} pieces "
          f"({kept[1]:6.1f} ac)  trim={ta - kept[1]:6.1f} ac")

# %% [markdown]
# ### 13.4 Build the trimmed output FC
#
# For each nest:
# - If under target → copy original geometry, `Trimmed=0`, `OrigAc =
#   TotalAc`.
# - If over target → dissolve the kept pieces, recompute geodesic acres
#   on the result, `Trimmed=1`, `OrigAc =` pre-trim TotalAc.
#
# `TotalAc` in the new FC is always the post-trim acres. `OrigAc`
# preserves the pre-trim value for audit.

# %%
TRIM_FC = OUTPUT_GDB + "\\" + "TRPA_Goshawk_Threshold_Zone_Trimmed"
if arcpy.Exists(TRIM_FC):
    arcpy.management.Delete(TRIM_FC)

sr = arcpy.Describe(THRESHOLD_FC).spatialReference
arcpy.management.CreateFeatureclass(
    OUTPUT_GDB, "TRPA_Goshawk_Threshold_Zone_Trimmed", "POLYGON",
    spatial_reference=sr,
)
for fn, ft, kw in [
    ("NestID", "TEXT", {"field_length": 64}),
    ("NestOID", "LONG", {}),
    ("Location", "TEXT", {"field_length": 128}),
    ("BufAc", "DOUBLE", {}),
    ("HighAc", "DOUBLE", {}),
    ("ModAc", "DOUBLE", {}),
    ("TotalAc", "DOUBLE", {}),
    ("OrigAc", "DOUBLE", {}),
    ("Picks", "LONG", {}),
    ("Sec", "DOUBLE", {}),
    ("Trimmed", "SHORT", {}),
    ("Short", "SHORT", {}),
]:
    arcpy.management.AddField(TRIM_FC, fn, ft, **kw)

ic_fields = [
    "SHAPE@", "NestID", "NestOID", "Location",
    "BufAc", "HighAc", "ModAc", "TotalAc", "OrigAc",
    "Picks", "Sec", "Trimmed", "Short",
]

t0 = time.time()
n_trimmed = 0
with arcpy.da.InsertCursor(TRIM_FC, ic_fields) as ic:
    for nid, (noid, loc, ba, ha, ma, orig_ta, picks, sec, geom) in all_threshold_rows.items():
        if nid in keep_oids_per_nest:
            keep_oids, _running = keep_oids_per_nest[nid]
            if not keep_oids:
                # No pieces to keep (very rare) - leave row alone with note
                new_geom = geom
                new_ta = orig_ta
                trimmed_flag = 0
            else:
                where = f"{oid_field_id1} IN ({','.join(str(o) for o in keep_oids)})"
                sel_lyr = mem("trim_sel")
                arcpy.management.MakeFeatureLayer(ID1_FC, sel_lyr, where)
                diss = mem("trim_diss")
                arcpy.management.Dissolve(sel_lyr, diss)
                arcpy.management.Delete(sel_lyr)
                with arcpy.da.SearchCursor(diss, ["SHAPE@"]) as dc:
                    new_geom = next(dc)[0]
                add_acres(diss, "Acres", "AREA_GEODESIC")
                new_ta = sum_field(diss, "Acres")
                arcpy.management.Delete(diss)
                trimmed_flag = 1
                n_trimmed += 1
        else:
            new_geom = geom
            new_ta = orig_ta
            trimmed_flag = 0

        short = 1 if new_ta is not None and new_ta < TARGET_AC - 0.01 else 0
        ic.insertRow([
            new_geom, nid, noid, loc,
            float(ba or 0), float(ha or 0), float(ma or 0),
            float(new_ta or 0), float(orig_ta or 0),
            int(picks or 0), float(sec or 0),
            trimmed_flag, short,
        ])

print(f"Trim done in {time.time()-t0:.1f}s")
print(f"  Trimmed: {n_trimmed}")
print(f"  Output:  {TRIM_FC}")

# %% [markdown]
# ### 13.5 Verify post-trim distribution
#
# Quick scan of the trimmed FC to confirm no row exceeds `TARGET_AC` and
# the trimmed counts look right.

# %%
totals = []
trim_count = 0
short_count = 0
over_count = 0
with arcpy.da.SearchCursor(
    TRIM_FC, ["NestID", "TotalAc", "OrigAc", "Trimmed", "Short"]
) as cur:
    for nid, ta, oa, tflag, sflag in cur:
        totals.append(ta)
        if tflag: trim_count += 1
        if sflag: short_count += 1
        if ta is not None and ta > TARGET_AC + 0.01:
            over_count += 1
            print(f"  STILL OVER: {nid} TotalAc={ta:.2f}")

import statistics
totals = [t for t in totals if t is not None]
print(f"\nRows:    {len(totals)}")
print(f"Mean:    {statistics.mean(totals):.1f}")
print(f"Median:  {statistics.median(totals):.1f}")
print(f"Min:     {min(totals):.1f}")
print(f"Max:     {max(totals):.1f}")
print(f"Trimmed: {trim_count}")
print(f"Short:   {short_count}")
print(f"Over:    {over_count}  (should be 0)")
